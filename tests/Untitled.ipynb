# %%
import aseg_gdf2

# %%
gdf = aseg_gdf2.read(r'example_datasets/9a13704a/Mugrave_WB_MGA52')

# %%
gdf.df()[[n for n in gdf.column_names() if n.startswith('Con_doi')]]
# Out:
#     Con_doi[0]  Con_doi[1]  Con_doi[2]  Con_doi[3]  Con_doi[4]  Con_doi[5]  \
# 0     28.76870    31.88776    46.04052    83.68201   157.48031   231.53508
# 1     31.06555    35.47357    51.17707    92.08103   165.37126   235.73786
# 2     38.18251    42.48088    59.91612   103.59474   174.79462   232.07241
# 3     47.61905    51.84033    70.17544   114.31184   178.79492   219.92523
# 4     58.58231    61.12469    77.45933   118.04982   173.64126   209.51184
# 5     62.93266    66.13757    80.38585   116.69973   164.66326   201.20724
# 6     59.27682    63.53240    77.51938   112.06993   155.83606   191.31433
# 7     51.12474    54.88474    68.77579   103.32713   145.45455   173.85257
# 8     42.21190    45.76659    59.73716    94.33962   136.29549   157.62926
# 9     35.05082    38.77472    52.27392    86.35579   131.78703   151.90643
# 10    32.00000    35.73981    48.49661    81.49959   128.20513   149.29830
# ...

# %%
gdf.get_field_definition('Con_doi')
# Out:
# {'name': 'Con_doi',
#  'format': '30F15.5',
#  'unit': 'mS/m',
#  'null': '-9999999.99999',
#  'long_name': '',
#  'comment': 'masked to the depth of investigation',
#  'cols': 30,
#  'width': 15}

# %%
gdf.get_field('Con_doi')[4:6, -6]
# Out:
# array([174.27675,       nan])
